# %%
from ultralytics import YOLO
import os
import matplotlib.pyplot as plt
from ray import tune

# %%
# Load the YOLO model
model = YOLO('yolo11n.pt')  

result_grid = model.tune(data="instruments.yaml", use_ray=True)

# # Run Ray Tune on the model
# result_grid = model.tune(
#     data="./instruments.yaml",
#     space={"lr0": tune.uniform(1e-5, 1e-1)},
#     epochs=50,
#     use_ray=True,
# )
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-12-10 14:48:01</td></tr>
# <tr><td>Running for: </td><td>00:00:05.27        </td></tr>
# <tr><td>Memory:      </td><td>14.4/15.3 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=0<br>Bracket: Iter 90.000: None | Iter 30.000: None | Iter 10.000: None<br>Logical resource usage: 16.0/16 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#   : ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
#
#
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name       </th><th>status  </th><th>loc            </th><th style="text-align: right;">      bgr</th><th style="text-align: right;">      box</th><th style="text-align: right;">     cls</th><th style="text-align: right;">  copy_paste</th><th style="text-align: right;">  degrees</th><th style="text-align: right;">   fliplr</th><th style="text-align: right;">  flipud</th><th style="text-align: right;">     hsv_h</th><th style="text-align: right;">    hsv_s</th><th style="text-align: right;">    hsv_v</th><th style="text-align: right;">      lr0</th><th style="text-align: right;">     lrf</th><th style="text-align: right;">    mixup</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  mosaic</th><th style="text-align: right;">  perspective</th><th style="text-align: right;">    scale</th><th style="text-align: right;">    shear</th><th style="text-align: right;">  translate</th><th style="text-align: right;">  warmup_epochs</th><th style="text-align: right;">  warmup_momentum</th><th style="text-align: right;">  weight_decay</th></tr>
# </thead>
# <tbody>
# <tr><td>_tune_116ab_00000</td><td>RUNNING </td><td>127.0.0.1:54632</td><td style="text-align: right;">0.42144  </td><td style="text-align: right;">0.103036 </td><td style="text-align: right;">0.728087</td><td style="text-align: right;">    0.622118</td><td style="text-align: right;">  1.29082</td><td style="text-align: right;">0.79879  </td><td style="text-align: right;">0.816932</td><td style="text-align: right;">0.00187978</td><td style="text-align: right;">0.475576 </td><td style="text-align: right;">0.391405 </td><td style="text-align: right;">0.0679512</td><td style="text-align: right;">0.365573</td><td style="text-align: right;">0.0645822</td><td style="text-align: right;">  0.771893</td><td style="text-align: right;">0.885368</td><td style="text-align: right;">  0.000254791</td><td style="text-align: right;">0.0682074</td><td style="text-align: right;">5.46441  </td><td style="text-align: right;">  0.0442923</td><td style="text-align: right;">      3.86886  </td><td style="text-align: right;">         0.739573</td><td style="text-align: right;">   0.000846358</td></tr>
# <tr><td>_tune_116ab_00001</td><td>RUNNING </td><td>127.0.0.1:54604</td><td style="text-align: right;">0.856052 </td><td style="text-align: right;">0.0851978</td><td style="text-align: right;">0.387353</td><td style="text-align: right;">    0.74495 </td><td style="text-align: right;"> 27.5331 </td><td style="text-align: right;">0.0302877</td><td style="text-align: right;">0.666176</td><td style="text-align: right;">0.0590692 </td><td style="text-align: right;">0.505667 </td><td style="text-align: right;">0.472499 </td><td style="text-align: right;">0.0515606</td><td style="text-align: right;">0.897138</td><td style="text-align: right;">0.252888 </td><td style="text-align: right;">  0.715866</td><td style="text-align: right;">0.154707</td><td style="text-align: right;">  0.000537236</td><td style="text-align: right;">0.397836 </td><td style="text-align: right;">0.0571842</td><td style="text-align: right;">  0.265797 </td><td style="text-align: right;">      0.368617 </td><td style="text-align: right;">         0.727951</td><td style="text-align: right;">   0.000691274</td></tr>
hsv_2024-12-10_14-47-56
# 2024-12-10 14:47:59,040	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\YASIRU~1\AppData\Local\Temp\ray\session_2024-12-10_14-47-49_726954_50404\artifacts\2024-12-10_14-47-55\_tune_2024-12-10_14-47-55\driver_artifacts\_tune_116ab_00000_0_bgr=0.4214,box=0.1030,cls=0.7281,copy_paste=0.6221,degrees=1.2908,fliplr=0.7988,flipud=0.8169,hsv_h=0.0019,hsv_2024-12-10_14-47-56
# 2024-12-10 14:47:59,068	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\YASIRU~1\AppData\Local\Temp\ray\session_2024-12-10_14-47-49_726954_50404\artifacts\2024-12-10_14-47-55\_tune_2024-12-10_14-47-55\driver_artifacts\_tune_116ab_00001_1_bgr=0.8561,box=0.0852,cls=0.3874,copy_paste=0.7449,degrees=27.5331,fliplr=0.0303,flipud=0.6662,hsv_h=0.0591,hs_2024-12-10_14-47-56
# 2024-12-10 14:47:59,070	WARNING trial.py:647 -- The path to the trial log directory is too long (max length: 260. Consider using `trial_dirname_creator` to shorten the path. Path: C:\Users\YASIRU~1\AppData\Local\Temp\ray\session_2024-12-10_14-47-49_726954_50404\artifacts\2024-12-10_14-47-55\_tune_2024-12-10_14-47-55\driver_artifacts\_tune_116ab_00001_1_bgr=0.8561,box=0.0852,cls=0.3874,copy_paste=0.7449,degrees=27.5331,fliplr=0.0303,flipud=0.6662,hsv_h=0.0591,hs_2024-12-10_14-47-56
# (_WandbLoggingActor pid=55188) wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# 2024-12-10 14:48:03,495	ERROR tune_controller.py:1331 -- Trial task failed for trial _tune_116ab_00000
# Traceback (most recent call last):
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\worker.py", line 2755, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\worker.py", line 906, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(AssertionError): ray::ImplicitFunc.train() (pid=54632, ip=127.0.0.1, actor_id=26fe2ba405ec18398e1250d001000000, repr=_tune)
#   File "python\ray\_raylet.pyx", line 1879, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1820, in ray._raylet.execute_task.function_executor
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\function_manager.py", line 696, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\air\_internal\util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\tuner.py", line 106, in _tune
#     results = model_to_train.train(**config)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\engine\model.py", line 800, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\engine\trainer.py", line 103, in __init__
#     self.device = select_device(self.args.device, self.args.batch)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\torch_utils.py", line 218, in select_device
#     s += f"{'' if i == 0 else space}CUDA:{d} ({get_gpu_info(i)})\n"  # bytes to MB
#                                                ^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\torch_utils.py", line 129, in get_gpu_info
#     properties = torch.cuda.get_device_properties(index)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\torch\cuda\__init__.py", line 526, in get_device_properties
#     raise AssertionError("Invalid device id")
# AssertionError: Invalid device id
# 2024-12-10 14:48:05,144	ERROR tune_controller.py:1331 -- Trial task failed for trial _tune_116ab_00001
# Traceback (most recent call last):
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\worker.py", line 2755, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\worker.py", line 906, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(AssertionError): ray::ImplicitFunc.train() (pid=54604, ip=127.0.0.1, actor_id=42adf6b519f1465fe45f7d9201000000, repr=_tune)
#   File "python\ray\_raylet.pyx", line 1879, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1820, in ray._raylet.execute_task.function_executor
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\function_manager.py", line 696, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\air\_internal\util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\tuner.py", line 106, in _tune
#     results = model_to_train.train(**config)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\engine\model.py", line 800, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\engine\trainer.py", line 103, in __init__
#     self.device = select_device(self.args.device, self.args.batch)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\torch_utils.py", line 218, in select_device
#     s += f"{'' if i == 0 else space}CUDA:{d} ({get_gpu_info(i)})\n"  # bytes to MB
#                                                ^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\torch_utils.py", line 129, in get_gpu_info
#     properties = torch.cuda.get_device_properties(index)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\torch\cuda\__init__.py", line 526, in get_device_properties
#     raise AssertionError("Invalid device id")
# AssertionError: Invalid device id
# ---------------------------------------------------------------------------
# RayTaskError(AssertionError)              Traceback (most recent call last)
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\air\execution\_internal\event_manager.py:110, in RayEventManager.resolve_future(self, future)
#     109 try:
# --> 110     result = ray.get(future)
#     111 except Exception as e:
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\_private\auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      20 auto_init_ray()
# ---> 21 return fn(*args, **kwargs)
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\_private\client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\_private\worker.py:2755, in get(object_refs, timeout)
#    2754 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2755 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2756 for i, value in enumerate(values):
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\_private\worker.py:906, in Worker.get_objects(self, object_refs, timeout, return_exceptions)
#     905 if isinstance(value, RayTaskError):
# --> 906     raise value.as_instanceof_cause()
#     907 else:
#
# RayTaskError(AssertionError): ray::ImplicitFunc.train() (pid=54604, ip=127.0.0.1, actor_id=42adf6b519f1465fe45f7d9201000000, repr=_tune)
#   File "python\ray\_raylet.pyx", line 1879, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1820, in ray._raylet.execute_task.function_executor
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\function_manager.py", line 696, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\air\_internal\util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\tuner.py", line 106, in _tune
#     results = model_to_train.train(**config)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\engine\model.py", line 800, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\engine\trainer.py", line 103, in __init__
#     self.device = select_device(self.args.device, self.args.batch)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\torch_utils.py", line 218, in select_device
#     s += f"{'' if i == 0 else space}CUDA:{d} ({get_gpu_info(i)})\n"  # bytes to MB
#                                                ^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\torch_utils.py", line 129, in get_gpu_info
#     properties = torch.cuda.get_device_properties(index)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\torch\cuda\__init__.py", line 526, in get_device_properties
#     raise AssertionError("Invalid device id")
# AssertionError: Invalid device id
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\execution\tune_controller.py:1245, in TuneController._schedule_trial_task.<locals>._on_error(tracked_actor, exception)
#    1244 try:
# -> 1245     on_error(trial, exception)
#    1246 except Exception as e:
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\execution\tune_controller.py:1332, in TuneController._trial_task_failure(self, trial, exception)
#    1331     logger.error(f"Trial task failed for trial {trial}", exc_info=exception)
# -> 1332 self._process_trial_failure(trial, exception=exception)
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\execution\tune_controller.py:1358, in TuneController._process_trial_failure(self, trial, exception)
#    1357 self._schedule_trial_stop(trial, exception=exception)
# -> 1358 self._callbacks.on_trial_error(
#    1359     iteration=self._iteration, trials=self._trials, trial=trial
#    1360 )
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\callback.py:422, in CallbackList.on_trial_error(self, **info)
#     421 for callback in self._callbacks:
# --> 422     callback.on_trial_error(**info)
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\logger\logger.py:167, in LoggerCallback.on_trial_error(self, iteration, trials, trial, **info)
#     164 def on_trial_error(
#     165     self, iteration: int, trials: List["Trial"], trial: "Trial", **info
#     166 ):
# --> 167     self.log_trial_end(trial, failed=True)
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\air\integrations\wandb.py:702, in WandbLoggerCallback.log_trial_end(self, trial, failed)
#     701 def log_trial_end(self, trial: "Trial", failed: bool = False):
# --> 702     self._signal_logging_actor_stop(trial=trial)
#     703     self._cleanup_logging_actors()
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\air\integrations\wandb.py:683, in WandbLoggerCallback._signal_logging_actor_stop(self, trial)
#     682 def _signal_logging_actor_stop(self, trial: "Trial"):
# --> 683     self._trial_queues[trial].put((_QueueItem.END, None))
#
# KeyError: _tune_116ab_00001
#
# During handling of the above exception, another exception occurred:
#
# TuneError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Load the YOLO model
#       2 model = YOLO('yolo11n.pt')
# ----> 4 result_grid = model.tune(data="instruments.yaml", use_ray=True)
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ultralytics\engine\model.py:851, in Model.tune(self, use_ray, iterations, *args, **kwargs)
#     848 if use_ray:
#     849     from ultralytics.utils.tuner import run_ray_tune
# --> 851     return run_ray_tune(self, max_samples=iterations, *args, **kwargs)
#     852 else:
#     853     from .tuner import Tuner
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\tuner.py:147, in run_ray_tune(model, space, grace_period, gpu_per_trial, max_samples, **train_args)
#     139 tuner = tune.Tuner(
#     140     trainable_with_resources,
#     141     param_space=space,
#     142     tune_config=tune.TuneConfig(scheduler=asha_scheduler, num_samples=max_samples),
#     143     run_config=RunConfig(callbacks=tuner_callbacks, storage_path=tune_dir),
#     144 )
#     146 # Run the hyperparameter search
# --> 147 tuner.fit()
#     149 # Get the results of the hyperparameter search
#     150 results = tuner.get_results()
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\tuner.py:377, in Tuner.fit(self)
#     345 """Executes hyperparameter tuning job as configured and returns result.
#     346
#     347 Failure handling:
#    (...)
#     373     RayTaskError: If user-provided trainable raises an exception
#     374 """
#     376 if not self._is_ray_client:
# --> 377     return self._local_tuner.fit()
#     378 else:
#     379     (
#     380         progress_reporter,
#     381         string_queue,
#     382     ) = self._prepare_remote_tuner_for_jupyter_progress_reporting()
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\impl\tuner_internal.py:476, in TunerInternal.fit(self)
#     474 param_space = copy.deepcopy(self.param_space)
#     475 if not self._is_restored:
# --> 476     analysis = self._fit_internal(trainable, param_space)
#     477 else:
#     478     analysis = self._fit_resume(trainable, param_space)
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\impl\tuner_internal.py:592, in TunerInternal._fit_internal(self, trainable, param_space)
#     579 """Fitting for a fresh Tuner."""
#     580 args = {
#     581     **self._get_tune_run_arguments(trainable),
#     582     **dict(
#    (...)
#     590     **self._tuner_kwargs,
#     591 }
# --> 592 analysis = run(
#     593     **args,
#     594 )
#     595 self.clear_remote_string_queue()
#     596 return analysis
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\tune.py:994, in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, resume, resume_config, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _remote, _remote_string_queue, _entrypoint)
#     992 try:
#     993     while not runner.is_finished() and not experiment_interrupted_event.is_set():
# --> 994         runner.step()
#     995         if has_verbosity(Verbosity.V1_EXPERIMENT):
#     996             _report_progress(runner, progress_reporter)
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\execution\tune_controller.py:685, in TuneController.step(self)
#     682 self._maybe_add_actors()
#     684 # Handle one event
# --> 685 if not self._actor_manager.next(timeout=0.1):
#     686     # If there are no actors running, warn about potentially
#     687     # insufficient resources
#     688     if not self._actor_manager.num_live_actors:
#     689         self._insufficient_resources_manager.on_no_available_trials(
#     690             self.get_trials()
#     691         )
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\air\execution\_internal\actor_manager.py:223, in RayActorManager.next(self, timeout)
#     221     self._actor_state_events.resolve_future(future)
#     222 elif future in actor_task_futures:
# --> 223     self._actor_task_events.resolve_future(future)
#     224 else:
#     225     self._handle_ready_resource_future()
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\air\execution\_internal\event_manager.py:113, in RayEventManager.resolve_future(self, future)
#     111 except Exception as e:
#     112     if on_error:
# --> 113         on_error(e)
#     114     else:
#     115         raise e
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\air\execution\_internal\actor_manager.py:771, in RayActorManager._schedule_tracked_actor_task.<locals>.on_error(exception)
#     770 def on_error(exception: Exception):
# --> 771     self._actor_task_failed(
#     772         tracked_actor_task=tracked_actor_task, exception=exception
#     773     )
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\air\execution\_internal\actor_manager.py:288, in RayActorManager._actor_task_failed(self, tracked_actor_task, exception)
#     285 elif isinstance(exception, RayTaskError):
#     286     # Otherwise only the task failed. Invoke callback
#     287     if tracked_actor_task._on_error:
# --> 288         tracked_actor_task._on_error(tracked_actor, exception)
#     289 else:
#     290     raise RuntimeError(
#     291         f"Caught unexpected exception: {exception}"
#     292     ) from exception
#
# File ~\.conda\envs\torch-env\Lib\site-packages\ray\tune\execution\tune_controller.py:1254, in TuneController._schedule_trial_task.<locals>._on_error(tracked_actor, exception)
#    1252     raise e
#    1253 else:
# -> 1254     raise TuneError(traceback.format_exc())
#
# TuneError: Traceback (most recent call last):
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\air\execution\_internal\event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\worker.py", line 2755, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\worker.py", line 906, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(AssertionError): ray::ImplicitFunc.train() (pid=54604, ip=127.0.0.1, actor_id=42adf6b519f1465fe45f7d9201000000, repr=_tune)
#   File "python\ray\_raylet.pyx", line 1879, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1820, in ray._raylet.execute_task.function_executor
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\_private\function_manager.py", line 696, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\air\_internal\util.py", line 107, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\trainable\function_trainable.py", line 250, in _trainable_func
#     output = fn()
#              ^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\tuner.py", line 106, in _tune
#     results = model_to_train.train(**config)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\engine\model.py", line 800, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\engine\trainer.py", line 103, in __init__
#     self.device = select_device(self.args.device, self.args.batch)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\torch_utils.py", line 218, in select_device
#     s += f"{'' if i == 0 else space}CUDA:{d} ({get_gpu_info(i)})\n"  # bytes to MB
#                                                ^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ultralytics\utils\torch_utils.py", line 129, in get_gpu_info
#     properties = torch.cuda.get_device_properties(index)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\torch\cuda\__init__.py", line 526, in get_device_properties
#     raise AssertionError("Invalid device id")
# AssertionError: Invalid device id
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\execution\tune_controller.py", line 1245, in _on_error
#     on_error(trial, exception)
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\execution\tune_controller.py", line 1332, in _trial_task_failure
#     self._process_trial_failure(trial, exception=exception)
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\execution\tune_controller.py", line 1358, in _process_trial_failure
#     self._callbacks.on_trial_error(
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\callback.py", line 422, in on_trial_error
#     callback.on_trial_error(**info)
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\tune\logger\logger.py", line 167, in on_trial_error
#     self.log_trial_end(trial, failed=True)
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\air\integrations\wandb.py", line 702, in log_trial_end
#     self._signal_logging_actor_stop(trial=trial)
#   File "C:\Users\Yasiru Fernando\.conda\envs\torch-env\Lib\site-packages\ray\air\integrations\wandb.py", line 683, in _signal_logging_actor_stop
#     self._trial_queues[trial].put((_QueueItem.END, None))
#     ~~~~~~~~~~~~~~~~~~^^^^^^^
# KeyError: _tune_116ab_00001
